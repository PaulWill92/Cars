# %%
from webcrawler import web_crawler

# %%
web_crawler()
# Out:
# Body styles = saloon, hatchback, 4x4, estate, coupe, convertible, or mpv.
# Enter a body style (or leave blank for all):
# Enter the amount of pages you want to scrape:  1
# Name to save file as (leave blank to not save):  cars
#     price(£)  mileage(mi)  door_count body_style  engine_size(cc)  \
# 0      17499        21452         4.0     Saloon           1999.0
# 2      14000        83990         4.0     Saloon           2143.0
# 3      27150         9316         4.0     Saloon           2993.0
# 5       5990        83807         4.0     Saloon           1685.0
# 7      17999        45605         4.0     Saloon           1995.0
# ..       ...          ...         ...        ...              ...
# 65      3995        88000         5.0        MPV           1490.0
# 66      3495       105311         5.0        MPV           1968.0
# 67     15498           10         5.0        MPV           1199.0
# 68      6495        24000         5.0        MPV           1198.0
# ...
